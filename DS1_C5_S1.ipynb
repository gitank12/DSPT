# %% [markdown]
# # C5_S1

# %%
#Mayota

# %%
import pandas as pd
import statistics as st
import seaborn as sns

# %%
# Task 1

# %%
cars_data = pd.read_csv('DS1_C5_S1_Descriptive_Analysis_Practice_Car_Data.csv')
cars_data
# Out:
#       Sl. No.        Make      Model        Variant  Displacement  Cylinders  \
# 0           0        Tata  Nano Genx             Xt         624.0        2.0
# 1           1        Tata  Nano Genx             Xe         624.0        2.0
# 2           2        Tata  Nano Genx        Emax Xm         624.0        2.0
# 3           3        Tata  Nano Genx            Xta         624.0        2.0
# 4           4        Tata  Nano Genx             Xm         624.0        2.0
# ...       ...         ...        ...            ...           ...        ...
# 1271     1271       Honda       City   Vx Mt Diesel        1498.0        4.0
# 1272     1272       Honda       City   Zx Mt Diesel        1498.0        4.0
# 1273     1273       Honda       City  Zx Cvt Petrol        1497.0        4.0
# 1274     1274       Honda       City   V Cvt Petrol        1497.0        4.0
# 1275     1275  Mitsubishi    Montero         3.2 At        3200.0        4.0
#
# ...

# %%
car = cars_data[['Make','Model','Displacement','City_Mileage_km_litre','Highway_Mileage_km_litre','Fuel_Tank_Capacity_litre','Minimum_Turning_Radius']]
car
# Out:
#             Make      Model  Displacement  City_Mileage_km_litre  \
# 0           Tata  Nano Genx         624.0                  23.60
# 1           Tata  Nano Genx         624.0                  23.60
# 2           Tata  Nano Genx         624.0                    NaN
# 3           Tata  Nano Genx         624.0                  23.60
# 4           Tata  Nano Genx         624.0                  23.60
# ...          ...        ...           ...                    ...
# 1271       Honda       City        1498.0                  22.60
# 1272       Honda       City        1498.0                  22.60
# 1273       Honda       City        1497.0                  18.00
# 1274       Honda       City        1497.0                  14.30
# 1275  Mitsubishi    Montero        3200.0                   8.25
#
#       Highway_Mileage_km_litre  Fuel_Tank_Capacity_litre  \
# 0                          NaN                      24.0
# 1                          NaN                      24.0
# ...

# %%
car
# Out:
#             Make      Model  Displacement  City_Mileage_km_litre  \
# 0           Tata  Nano Genx         624.0                  23.60
# 1           Tata  Nano Genx         624.0                  23.60
# 2           Tata  Nano Genx         624.0                    NaN
# 3           Tata  Nano Genx         624.0                  23.60
# 4           Tata  Nano Genx         624.0                  23.60
# ...          ...        ...           ...                    ...
# 1271       Honda       City        1498.0                  22.60
# 1272       Honda       City        1498.0                  22.60
# 1273       Honda       City        1497.0                  18.00
# 1274       Honda       City        1497.0                  14.30
# 1275  Mitsubishi    Montero        3200.0                   8.25
#
#       Highway_Mileage_km_litre  Fuel_Tank_Capacity_litre  \
# 0                          NaN                      24.0
# 1                          NaN                      24.0
# ...

# %%
car.describe()
# Out:
#        Displacement  City_Mileage_km_litre  Highway_Mileage_km_litre  \
# count   1264.000000             721.000000                476.000000
# mean    1858.804589              15.815381                 16.879706
# std     1063.152389               8.954285                  4.918816
# min       72.000000               2.000000                  4.000000
# 25%     1198.000000              11.500000                 13.800000
# 50%     1497.000000              15.290000                 17.190000
# 75%     1998.000000              19.200000                 20.500000
# max     7993.000000             110.000000                 25.600000
#
#        Fuel_Tank_Capacity_litre  Minimum_Turning_Radius
# count               1207.000000              895.000000
# mean                  52.119221                5.605687
# std                   16.458956                1.528075
# min                   15.000000                3.500000
# 25%                   40.000000                4.970000
# ...

# %%
Mean = car.describe().loc[['mean','50%']]
Mean
# Out:
#       Displacement  City_Mileage_km_litre  Highway_Mileage_km_litre  \
# mean   1858.804589              15.815381                 16.879706
# 50%    1497.000000              15.290000                 17.190000
#
#       Fuel_Tank_Capacity_litre  Minimum_Turning_Radius
# mean                 52.119221                5.605687
# 50%                  46.000000                5.250000

# %%
Mean.loc['S.D.',:] = car.std()
Mean
# Out:
# C:\Users\NELSON FERNANDES\AppData\Local\Temp/ipykernel_25312/792763637.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Mean.loc['S.D.',:] = car.std()
#       Displacement  City_Mileage_km_litre  Highway_Mileage_km_litre  \
# mean   1858.804589              15.815381                 16.879706
# 50%    1497.000000              15.290000                 17.190000
# S.D.   1063.152389               8.954285                  4.918816
#
#       Fuel_Tank_Capacity_litre  Minimum_Turning_Radius
# mean                 52.119221                5.605687
# 50%                  46.000000                5.250000
# S.D.                 16.458956                1.528075

# %%
Mean.loc['Coeff.Var.',:] = (car.std()/car.mean())*100
Mean
# Out:
# C:\Users\NELSON FERNANDES\AppData\Local\Temp/ipykernel_25312/201189863.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Mean.loc['Coeff.Var.',:] = (car.std()/car.mean())*100
#             Displacement  City_Mileage_km_litre  Highway_Mileage_km_litre  \
# mean         1858.804589              15.815381                 16.879706
# 50%          1497.000000              15.290000                 17.190000
# S.D.         1063.152389               8.954285                  4.918816
# Coeff.Var.     57.195490              56.617575                 29.140413
#
#             Fuel_Tank_Capacity_litre  Minimum_Turning_Radius
# mean                       52.119221                5.605687
# 50%                        46.000000                5.250000
# S.D.                       16.458956                1.528075
# ...

# %%
A = car[(car.Make=='Maruti Suzuki')|(car.Make=='Toyota')|(car.Make=='Mahindra')]
A
# Out:
#                Make   Model  Displacement  City_Mileage_km_litre  \
# 24    Maruti Suzuki    Eeco        1196.0                   12.0
# 25    Maruti Suzuki    Eeco        1196.0                   12.0
# 26    Maruti Suzuki    Eeco        1196.0                   11.0
# 27    Maruti Suzuki    Eeco        1196.0                    NaN
# 28    Maruti Suzuki    Eeco        1196.0                    NaN
# ...             ...     ...           ...                    ...
# 1237         Toyota   Yaris        1496.0                    NaN
# 1238         Toyota   Yaris        1498.0                    NaN
# 1255       Mahindra  Verito        1461.0                   18.0
# 1256       Mahindra  Verito        1461.0                   18.0
# 1257       Mahindra  Verito        1461.0                   18.0
#
#       Highway_Mileage_km_litre  Fuel_Tank_Capacity_litre  \
# 24                       15.00                      40.0
# 25                       15.00                      40.0
# ...

# %%
MS = car[(car.Make=='Maruti Suzuki')]
MS
# Out:
#                Make Model  Displacement  City_Mileage_km_litre  \
# 24    Maruti Suzuki  Eeco        1196.0                  12.00
# 25    Maruti Suzuki  Eeco        1196.0                  12.00
# 26    Maruti Suzuki  Eeco        1196.0                  11.00
# 27    Maruti Suzuki  Eeco        1196.0                    NaN
# 28    Maruti Suzuki  Eeco        1196.0                    NaN
# ...             ...   ...           ...                    ...
# 1098  Maruti Suzuki  Ciaz        1462.0                    NaN
# 1099  Maruti Suzuki  Ciaz        1462.0                    NaN
# 1100  Maruti Suzuki  Ciaz        1498.0                  26.82
# 1101  Maruti Suzuki  Ciaz        1498.0                  26.32
# 1102  Maruti Suzuki  Ciaz        1498.0                  26.32
#
#       Highway_Mileage_km_litre  Fuel_Tank_Capacity_litre  \
# 24                        15.0                      40.0
# 25                        15.0                      40.0
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1])
plt.boxplot([MS['Displacement']],vert = 0)
ax.set_yticklabels(['Maruti Suzuki'])
plt.show()

# %%
B = car[(car.Make=='Toyota')]
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1])
plt.boxplot([B['Displacement']],vert = 0)
ax.set_yticklabels(['Toyota'])
plt.show()

# %%
C = car[(car.Make=='Mahindra')]
fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0,0,1,1])
plt.boxplot([C['Displacement']],vert = 0)
ax.set_yticklabels(['Mahindra'])
plt.show()

# %%
C['Displacement'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
B['Displacement'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
C['Displacement'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Task 2

# %%
car2 = cars_data[['Make','Displacement','Cylinders','City_Mileage_km_litre','Highway_Mileage_km_litre','Fuel_Type','Kerb_Weight']]
car2
# Out:
#             Make  Displacement  Cylinders  City_Mileage_km_litre  \
# 0           Tata         624.0        2.0                  23.60
# 1           Tata         624.0        2.0                  23.60
# 2           Tata         624.0        2.0                    NaN
# 3           Tata         624.0        2.0                  23.60
# 4           Tata         624.0        2.0                  23.60
# ...          ...           ...        ...                    ...
# 1271       Honda        1498.0        4.0                  22.60
# 1272       Honda        1498.0        4.0                  22.60
# 1273       Honda        1497.0        4.0                  18.00
# 1274       Honda        1497.0        4.0                  14.30
# 1275  Mitsubishi        3200.0        4.0                   8.25
#
#       Highway_Mileage_km_litre Fuel_Type Kerb_Weight
# 0                          NaN    Petrol      660 kg
# 1                          NaN    Petrol      725 kg
# ...

# %%
car2.dropna(inplace=True)
# Out:
# C:\Users\NELSON FERNANDES\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
car2
# Out:
#                Make  Displacement  Cylinders  City_Mileage_km_litre  \
# 24    Maruti Suzuki        1196.0        4.0                  12.00
# 25    Maruti Suzuki        1196.0        4.0                  12.00
# 26    Maruti Suzuki        1196.0        4.0                  11.00
# 29    Maruti Suzuki         998.0        3.0                  14.00
# 30    Maruti Suzuki         998.0        3.0                  14.00
# ...             ...           ...        ...                    ...
# 1271          Honda        1498.0        4.0                  22.60
# 1272          Honda        1498.0        4.0                  22.60
# 1273          Honda        1497.0        4.0                  18.00
# 1274          Honda        1497.0        4.0                  14.30
# 1275     Mitsubishi        3200.0        4.0                   8.25
#
#       Highway_Mileage_km_litre Fuel_Type Kerb_Weight
# 24                       15.00    Petrol      920 kg
# ...

# %%
plt.hist(car2['Displacement'])
# Out:
# (array([ 31., 753., 275., 117.,  27.,  13.,  23.,   7.,  16.,   2.]),
#  array([  72. ,  864.1, 1656.2, 2448.3, 3240.4, 4032.5, 4824.6, 5616.7,
#         6408.8, 7200.9, 7993. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(car2['Fuel_Type'])
# Out:
# (array([643.,   0.,  16.,   0., 582.,   0.,   6.,   0.,  15.,  14.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)
